# %% [markdown]
# # Chapter 2: Programming Language Syntax

# %% [markdown]
# ### 2.1 Specifying syntax: regex and CFG
# - Tokens can be constructed from individual characters using three formal rules
#     1. Concatenation
#     2. Alternation
#     3. Kleene closure (repitition)
# - In addition, with *recursion*, a regular language becomes *context-free language*, generated by context-free grammar.
# - Tokens and regular expressions
#     - To specify tokens, we use notation of regular expressions
#         1. A character
#         2. Empty string
#         3. Two regex expressions next to each other, meaning any string generated by the first regex, followed by a string generated by the second regex
#         4. Two regex separated by a vertical bar |, meaning any string generated by either regex
#         5. A regex followed by a Kleene star, meaning a concatenation of zero or more strings generated by the expression in front of the star
